# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/yanak/machine-learning-exercise/blob/master/tutorial.ipynb)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool

# %%
from subprocess import check_output
print(check_output(["ls", "pokemon.csv"]).decode("utf8"))
# Out:
# pokemon.csv

# %%
data = pd.read_csv('pokemon.csv')

# %%
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data1 = data.head()
data2 = data.tail()
conc_data_row = pd.concat([data1,data2], axis=0, ignore_index=True)
conc_data_row
# Out:
#      #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1       Bulbasaur    Grass  Poison  45      49       49       65
# 1    2         Ivysaur    Grass  Poison  60      62       63       80
# 2    3        Venusaur    Grass  Poison  80      82       83      100
# 3    4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4    5      Charmander     Fire     NaN  39      52       43       60
# 5  796         Diancie     Rock   Fairy  50     100      150      100
# 6  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 7  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 8  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 9  800       Volcanion     Fire   Water  80     110      120      130
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5      150     50           6       True
# 6      110    110           6       True
# 7      130     70           6       True
# 8      130     80           6       True
# 9       90     70           6       True

# %%
data1 = data['Attack'].head()
data2 = data['Defense'].head()
conc_data_col = pd.concat([data1, data2], axis=1)
conc_data_col
# Out:
#    Attack  Defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3     100      123
# 4      52       43

# %%
#from google.colab import auth
#auth.authenticate_user()

# %%
# Create a local file to upload.
# with open('/tmp/to_upload.txt', 'w') as f:
#   f.write('my sample file')

# print('/tmp/to_upload.txt contains:')
# !ls

# %%
# First, we need to set our project. Replace the assignment below
# with your project ID.
#project_id = 'kaggle-217713'

# %%
# Finally, dump the contents of our newly copied file to make sure everything worked.
#!gsutil ls gs://kaggle3/tutorial/input/pokemon.csv

# %%
#!gsutil cp gs://kaggle3/tutorial/input/pokemon.csv /content/pokemon.csv

# %% [markdown]
# # Tutorial

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool

# %%
data = pd.read_csv('pokemon.csv')

# %%
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.shape
# Out:
# (800, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.6+ KB

# %%
print(data['Type 1'].value_counts(dropna=False))
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ghost        32
# Ground       32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
data.boxplot(column='Attack',by = 'Legendary')

# %%
country = ["Spain","France"]
population = ["11","12"]
list_label = ["country","population"]
list_col = [country, population]
zipped = list(zip(list_label, list_col))
data_dict = dict(zipped)
df = pd.DataFrame(data_dict)
df
# Out:
#   country population
# 0   Spain         11
# 1  France         12

# %%
df["capital"] = ["madrid", "paris"]
df
# Out:
#   country population capital
# 0   Spain         11  madrid
# 1  France         12   paris

# %%
df["income"] = 0
df
# Out:
#   country population capital  income
# 0   Spain         11  madrid       0
# 1  France         12   paris       0

# %% [markdown]
# # Visual exploratory data analysis

# %%
data1 = data.loc[:, ["Attack", "Defense", "Speed"]]
data1.plot()

# %%
data1.plot(subplots=True)
plt.show()

# %%
data1.plot(kind="scatter", x="Attack", y="Defense")
plt.show()

# %%
data1.plot(kind="hist", y="Defense", bins=50, range=(0,250), normed=True)

# %%
fig, axes = plt.subplots(nrows=2, ncols=1)
data1.plot(kind="hist", y="Defense", bins=50, range=(0,250), normed=True, ax=axes[0])
data1.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),normed = True,ax = axes[1],cumulative = True)
plt.savefig('graph.png')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py'>

# %%
time_list = ["1992-03-08", "1992-04-12"]
print(type(time_list[1]))
datetime_object = pd.to_datetime(time_list)
print(type(datetime_object))
# Out:
# <class 'str'>
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
time_list = ["1992-03-08", "1992-04-12"]
print(type(time_list[1]))
datetime_object = pd.to_datetime(time_list)
print(type(datetime_object))
# Out:
# <class 'str'>
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
#import warnings
#warnings.filterwarnings("ignore")

data2 = data.head()
date_list = ["1992-01-10", "1992-02-10", "1992-03-10", "1993-03-15", "1993-03-16"]
datetime_object = pd.to_datetime(date_list)
data2["date"] = datetime_object

data2 = data2.set_index("date")
data2
# Out:
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-01-10  1      Bulbasaur  Grass  Poison  45      49       49       65
# 1992-02-10  2        Ivysaur  Grass  Poison  60      62       63       80
# 1992-03-10  3       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16  5     Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-01-10       65     45           1      False
# 1992-02-10       80     60           1      False
# 1992-03-10      100     80           1      False
# 1993-03-15      120     80           1      False
# 1993-03-16       50     65           1      False

# %%
#print(data2.loc["1993-03-16"])
print(data2.loc["1992-03-10":"1993-03-14"])
# Out:
#             #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# date
# 1992-03-10  3  Venusaur  Grass  Poison  80      82       83      100      100
#
#             Speed  Generation  Legendary
# date
# 1992-03-10     80           1      False

# %%
data2.resample("A").mean()
# Out:
#               #         HP     Attack  Defense    Sp. Atk    Sp. Def  \
# date
# 1992-12-31  2.0  61.666667  64.333333     65.0  81.666667  81.666667
# 1993-12-31  4.5  59.500000  76.000000     83.0  91.000000  85.000000
#
#                 Speed  Generation  Legendary
# date
# 1992-12-31  61.666667         1.0      False
# 1993-12-31  72.500000         1.0      False

# %%
data2.resample("M").mean()
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# date
# 1992-01-31  1.0  45.0    49.0     49.0     65.0     65.0   45.0         1.0
# 1992-02-29  2.0  60.0    62.0     63.0     80.0     80.0   60.0         1.0
# 1992-03-31  3.0  80.0    82.0     83.0    100.0    100.0   80.0         1.0
# 1992-04-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-05-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-06-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-07-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-08-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-09-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-10-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-11-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-12-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1993-01-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1993-02-28  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1993-03-31  4.5  59.5    76.0     83.0     91.0     85.0   72.5         1.0
#
#             Legendary
# date
# 1992-01-31        0.0
# 1992-02-29        0.0
# 1992-03-31        0.0
# 1992-04-30        NaN
# 1992-05-31        NaN
# 1992-06-30        NaN
# 1992-07-31        NaN
# 1992-08-31        NaN
# 1992-09-30        NaN
# 1992-10-31        NaN
# 1992-11-30        NaN
# 1992-12-31        NaN
# 1993-01-31        NaN
# 1993-02-28        NaN
# 1993-03-31        0.0

# %%
data2.resample("M").mean().interpolate("linear")
# Out:
#                 #         HP  Attack  Defense  Sp. Atk  Sp. Def   Speed  \
# date
# 1992-01-31  1.000  45.000000    49.0     49.0    65.00    65.00  45.000
# 1992-02-29  2.000  60.000000    62.0     63.0    80.00    80.00  60.000
# 1992-03-31  3.000  80.000000    82.0     83.0   100.00   100.00  80.000
# 1992-04-30  3.125  78.291667    81.5     83.0    99.25    98.75  79.375
# 1992-05-31  3.250  76.583333    81.0     83.0    98.50    97.50  78.750
# 1992-06-30  3.375  74.875000    80.5     83.0    97.75    96.25  78.125
# 1992-07-31  3.500  73.166667    80.0     83.0    97.00    95.00  77.500
# 1992-08-31  3.625  71.458333    79.5     83.0    96.25    93.75  76.875
# 1992-09-30  3.750  69.750000    79.0     83.0    95.50    92.50  76.250
# 1992-10-31  3.875  68.041667    78.5     83.0    94.75    91.25  75.625
# 1992-11-30  4.000  66.333333    78.0     83.0    94.00    90.00  75.000
# 1992-12-31  4.125  64.625000    77.5     83.0    93.25    88.75  74.375
# 1993-01-31  4.250  62.916667    77.0     83.0    92.50    87.50  73.750
# 1993-02-28  4.375  61.208333    76.5     83.0    91.75    86.25  73.125
# 1993-03-31  4.500  59.500000    76.0     83.0    91.00    85.00  72.500
#
#             Generation  Legendary
# date
# 1992-01-31         1.0        0.0
# 1992-02-29         1.0        0.0
# 1992-03-31         1.0        0.0
# 1992-04-30         1.0        0.0
# 1992-05-31         1.0        0.0
# 1992-06-30         1.0        0.0
# 1992-07-31         1.0        0.0
# 1992-08-31         1.0        0.0
# 1992-09-30         1.0        0.0
# 1992-10-31         1.0        0.0
# 1992-11-30         1.0        0.0
# 1992-12-31         1.0        0.0
# 1993-01-31         1.0        0.0
# 1993-02-28         1.0        0.0
# 1993-03-31         1.0        0.0

# %%
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.loc[0, ["HP"]]
# Out:
# HP    45
# Name: 0, dtype: object

# %%
data[["HP", "Attack"]]
# Out:
#       HP  Attack
# 0     45      49
# 1     60      62
# 2     80      82
# 3     80     100
# 4     39      52
# 5     58      64
# 6     78      84
# 7     78     130
# 8     78     104
# 9     44      48
# 10    59      63
# 11    79      83
# 12    79     103
# 13    45      30
# 14    50      20
# 15    60      45
# 16    40      35
# 17    45      25
# 18    65      90
# 19    65     150
# 20    40      45
# 21    63      60
# 22    83      80
# 23    83      80
# 24    30      56
# 25    55      81
# 26    40      60
# 27    65      90
# 28    35      60
# 29    60      85
# ..   ...     ...
# 770   95      65
# 771   78      92
# 772   67      58
# 773   50      50
# 774   45      50
# 775   68      75
# 776   90     100
# 777   57      80
# 778   43      70
# 779   85     110
# 780   49      66
# 781   44      66
# 782   54      66
# 783   59      66
# 784   65      90
# 785   55      85
# 786   75      95
# 787   85     100
# 788   55      69
# 789   95     117
# 790   40      30
# 791   85      70
# 792  126     131
# 793  126     131
# 794  108     100
# 795   50     100
# 796   50     160
# 797   80     110
# 798   80     160
# 799   80     110
#
# [800 rows x 2 columns]

# %%
print(type(data["HP"]))
print(type(data[["HP"]]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
data.loc[1:10, "HP":"Defense"]
# Out:
#     HP  Attack  Defense
# 1   60      62       63
# 2   80      82       83
# 3   80     100      123
# 4   39      52       43
# 5   58      64       58
# 6   78      84       78
# 7   78     130      111
# 8   78     104       78
# 9   44      48       65
# 10  59      63       80

# %%
data.loc[10:1:-1, "HP":"Defense"]
# Out:
#     HP  Attack  Defense
# 10  59      63       80
# 9   44      48       65
# 8   78     104       78
# 7   78     130      111
# 6   78      84       78
# 5   58      64       58
# 4   39      52       43
# 3   80     100      123
# 2   80      82       83
# 1   60      62       63

# %%
data.loc[1:10, "Speed":]
# Out:
#     Speed  Generation  Legendary
# 1      60           1      False
# 2      80           1      False
# 3      80           1      False
# 4      65           1      False
# 5      80           1      False
# 6     100           1      False
# 7     100           1      False
# 8     100           1      False
# 9      43           1      False
# 10     58           1      False

# %%
boolean = data.HP > 200
data[boolean]
# Out:
#        #     Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  122  Chansey  Normal    NaN  250       5        5       35      105
# 261  262  Blissey  Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary
# 121     50           1      False
# 261     55           2      False

# %%
first_filter = data.HP > 200
second_filter = data.Speed > 35
data[first_filter & second_filter]
# Out:
#        #     Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  122  Chansey  Normal    NaN  250       5        5       35      105
# 261  262  Blissey  Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary
# 121     50           1      False
# 261     55           2      False

# %%
data.HP[data.Speed < 15]
# Out:
# 230     20
# 359     45
# 486     50
# 495    135
# 658     44
# Name: HP, dtype: int64

# %%
def div(n):
   return n/2
  
data.HP.apply(div)
# Out:
# 0      22.5
# 1      30.0
# 2      40.0
# 3      40.0
# 4      19.5
# 5      29.0
# 6      39.0
# 7      39.0
# 8      39.0
# 9      22.0
# 10     29.5
# 11     39.5
# 12     39.5
# 13     22.5
# 14     25.0
# 15     30.0
# 16     20.0
# 17     22.5
# 18     32.5
# 19     32.5
# 20     20.0
# 21     31.5
# 22     41.5
# 23     41.5
# 24     15.0
# 25     27.5
# 26     20.0
# 27     32.5
# 28     17.5
# 29     30.0
#        ...
# 770    47.5
# 771    39.0
# 772    33.5
# 773    25.0
# 774    22.5
# 775    34.0
# 776    45.0
# 777    28.5
# 778    21.5
# 779    42.5
# 780    24.5
# 781    22.0
# 782    27.0
# 783    29.5
# 784    32.5
# 785    27.5
# 786    37.5
# 787    42.5
# 788    27.5
# 789    47.5
# 790    20.0
# 791    42.5
# 792    63.0
# 793    63.0
# 794    54.0
# 795    25.0
# 796    25.0
# 797    40.0
# 798    40.0
# 799    40.0
# Name: HP, Length: 800, dtype: float64

# %%
data.HP.apply(lambda n : n/2)
# Out:
# 0      22.5
# 1      30.0
# 2      40.0
# 3      40.0
# 4      19.5
# 5      29.0
# 6      39.0
# 7      39.0
# 8      39.0
# 9      22.0
# 10     29.5
# 11     39.5
# 12     39.5
# 13     22.5
# 14     25.0
# 15     30.0
# 16     20.0
# 17     22.5
# 18     32.5
# 19     32.5
# 20     20.0
# 21     31.5
# 22     41.5
# 23     41.5
# 24     15.0
# 25     27.5
# 26     20.0
# 27     32.5
# 28     17.5
# 29     30.0
#        ...
# 770    47.5
# 771    39.0
# 772    33.5
# 773    25.0
# 774    22.5
# 775    34.0
# 776    45.0
# 777    28.5
# 778    21.5
# 779    42.5
# 780    24.5
# 781    22.0
# 782    27.0
# 783    29.5
# 784    32.5
# 785    27.5
# 786    37.5
# 787    42.5
# 788    27.5
# 789    47.5
# 790    20.0
# 791    42.5
# 792    63.0
# 793    63.0
# 794    54.0
# 795    25.0
# 796    25.0
# 797    40.0
# 798    40.0
# 799    40.0
# Name: HP, Length: 800, dtype: float64

# %%
data["total_power"] = data.Attack + data.Defense
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary  total_power
# 0     45           1      False           98
# 1     60           1      False          125
# 2     80           1      False          165
# 3     80           1      False          223
# 4     65           1      False           95

# %%
print(data.index.name)
# Out:
# None

# %%
data.index.name = "index_name"
data.head()
# Out:
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# index_name
# 0           1      Bulbasaur  Grass  Poison  45      49       49       65
# 1           2        Ivysaur  Grass  Poison  60      62       63       80
# 2           3       Venusaur  Grass  Poison  80      82       83      100
# 3           4  Mega Venusaur  Grass  Poison  80     100      123      122
# 4           5     Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary  total_power
# index_name
# 0                65     45           1      False           98
# 1                80     60           1      False          125
# 2               100     80           1      False          165
# 3               120     80           1      False          223
# 4                50     65           1      False           95

# %%
data.head()
# Out:
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# index_name
# 0           1      Bulbasaur  Grass  Poison  45      49       49       65
# 1           2        Ivysaur  Grass  Poison  60      62       63       80
# 2           3       Venusaur  Grass  Poison  80      82       83      100
# 3           4  Mega Venusaur  Grass  Poison  80     100      123      122
# 4           5     Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary  total_power
# index_name
# 0                65     45           1      False           98
# 1                80     60           1      False          125
# 2               100     80           1      False          165
# 3               120     80           1      False          223
# 4                50     65           1      False           95

# %%
data3 = data.copy()
data3.index = range(100,900,1)
data3.head()
# Out:
#      #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 100  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 101  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 102  3       Venusaur  Grass  Poison  80      82       83      100      100
# 103  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 104  5     Charmander   Fire     NaN  39      52       43       60       50
#
#      Speed  Generation  Legendary  total_power
# 100     45           1      False           98
# 101     60           1      False          125
# 102     80           1      False          165
# 103     80           1      False          223
# 104     65           1      False           95

# %%
data1 = data.set_index(["Type 1", "Type 2"])
data1.head(100)
# Out:
#                     #              Name   HP  Attack  Defense  Sp. Atk  \
# Type 1   Type 2
# Grass    Poison     1         Bulbasaur   45      49       49       65
#          Poison     2           Ivysaur   60      62       63       80
#          Poison     3          Venusaur   80      82       83      100
#          Poison     4     Mega Venusaur   80     100      123      122
# Fire     NaN        5        Charmander   39      52       43       60
#          NaN        6        Charmeleon   58      64       58       80
#          Flying     7         Charizard   78      84       78      109
#          Dragon     8  Mega Charizard X   78     130      111      130
#          Flying     9  Mega Charizard Y   78     104       78      159
# Water    NaN       10          Squirtle   44      48       65       50
#          NaN       11         Wartortle   59      63       80       65
#          NaN       12         Blastoise   79      83      100       85
#          NaN       13    Mega Blastoise   79     103      120      135
# Bug      NaN       14          Caterpie   45      30       35       20
#          NaN       15           Metapod   50      20       55       25
#          Flying    16        Butterfree   60      45       50       90
#          Poison    17            Weedle   40      35       30       20
#          Poison    18            Kakuna   45      25       50       25
#          Poison    19          Beedrill   65      90       40       45
#          Poison    20     Mega Beedrill   65     150       40       15
# Normal   Flying    21            Pidgey   40      45       40       35
#          Flying    22         Pidgeotto   63      60       55       50
#          Flying    23           Pidgeot   83      80       75       70
#          Flying    24      Mega Pidgeot   83      80       80      135
#          NaN       25           Rattata   30      56       35       25
#          NaN       26          Raticate   55      81       60       50
#          Flying    27           Spearow   40      60       30       31
#          Flying    28            Fearow   65      90       65       61
# Poison   NaN       29             Ekans   35      60       44       40
#          NaN       30             Arbok   60      85       69       65
# ...               ...               ...  ...     ...      ...      ...
# Psychic  NaN       71          Alakazam   55      50       45      135
#          NaN       72     Mega Alakazam   55      50       65      175
# Fighting NaN       73            Machop   70      80       50       35
#          NaN       74           Machoke   80     100       70       50
#          NaN       75           Machamp   90     130       80       65
# Grass    Poison    76        Bellsprout   50      75       35       70
#          Poison    77        Weepinbell   65      90       50       85
#          Poison    78        Victreebel   80     105       65      100
# Water    Poison    79         Tentacool   40      40       35       50
#          Poison    80        Tentacruel   80      70       65       80
# Rock     Ground    81           Geodude   40      80      100       30
#          Ground    82          Graveler   55      95      115       45
#          Ground    83             Golem   80     120      130       55
# Fire     NaN       84            Ponyta   50      85       55       65
#          NaN       85          Rapidash   65     100       70       80
# Water    Psychic   86          Slowpoke   90      65       65       40
#          Psychic   87           Slowbro   95      75      110      100
#          Psychic   88      Mega Slowbro   95      75      180      130
# Electric Steel     89         Magnemite   25      35       70       95
#          Steel     90          Magneton   50      60       95      120
# Normal   Flying    91        Farfetch'd   52      65       55       58
#          Flying    92             Doduo   35      85       45       35
#          Flying    93            Dodrio   60     110       70       60
# Water    NaN       94              Seel   65      45       55       45
#          Ice       95           Dewgong   90      70       80       70
# Poison   NaN       96            Grimer   80      80       50       40
#          NaN       97               Muk  105     105       75       65
# Water    NaN       98          Shellder   30      65      100       45
#          Ice       99          Cloyster   50      95      180       85
# Ghost    Poison   100            Gastly   30      35       30      100
#
#                   Sp. Def  Speed  Generation  Legendary  total_power
# Type 1   Type 2
# Grass    Poison        65     45           1      False           98
#          Poison        80     60           1      False          125
#          Poison       100     80           1      False          165
#          Poison       120     80           1      False          223
# Fire     NaN           50     65           1      False           95
#          NaN           65     80           1      False          122
#          Flying        85    100           1      False          162
#          Dragon        85    100           1      False          241
#          Flying       115    100           1      False          182
# Water    NaN           64     43           1      False          113
#          NaN           80     58           1      False          143
#          NaN          105     78           1      False          183
#          NaN          115     78           1      False          223
# Bug      NaN           20     45           1      False           65
#          NaN           25     30           1      False           75
#          Flying        80     70           1      False           95
#          Poison        20     50           1      False           65
#          Poison        25     35           1      False           75
#          Poison        80     75           1      False          130
#          Poison        80    145           1      False          190
# Normal   Flying        35     56           1      False           85
#          Flying        50     71           1      False          115
#          Flying        70    101           1      False          155
#          Flying        80    121           1      False          160
#          NaN           35     72           1      False           91
#          NaN           70     97           1      False          141
#          Flying        31     70           1      False           90
#          Flying        61    100           1      False          155
# Poison   NaN           54     55           1      False          104
#          NaN           79     80           1      False          154
# ...                   ...    ...         ...        ...          ...
# Psychic  NaN           95    120           1      False           95
#          NaN           95    150           1      False          115
# Fighting NaN           35     35           1      False          130
#          NaN           60     45           1      False          170
#          NaN           85     55           1      False          210
# Grass    Poison        30     40           1      False          110
#          Poison        45     55           1      False          140
#          Poison        70     70           1      False          170
# Water    Poison       100     70           1      False           75
#          Poison       120    100           1      False          135
# Rock     Ground        30     20           1      False          180
#          Ground        45     35           1      False          210
#          Ground        65     45           1      False          250
# Fire     NaN           65     90           1      False          140
#          NaN           80    105           1      False          170
# Water    Psychic       40     15           1      False          130
#          Psychic       80     30           1      False          185
#          Psychic       80     30           1      False          255
# Electric Steel         55     45           1      False          105
#          Steel         70     70           1      False          155
# Normal   Flying        62     60           1      False          120
#          Flying        35     75           1      False          130
#          Flying        60    100           1      False          180
# Water    NaN           70     45           1      False          100
#          Ice           95     70           1      False          150
# Poison   NaN           50     25           1      False          130
#          NaN          100     50           1      False          180
# Water    NaN           25     40           1      False          165
#          Ice           45     70           1      False          275
# Ghost    Poison        35     80           1      False           65
#
# [100 rows x 11 columns]

# %%
dic = {"treatment": ["A", "A", "B", "B"], "gender":["F", "M", "F", "M"], "response": [10, 45, 5, 9], "age":[15,4,72,65]}
df = pd.DataFrame(dic)
df
# Out:
#    age gender  response treatment
# 0   15      F        10         A
# 1    4      M        45         A
# 2   72      F         5         B
# 3   65      M         9         B

# %%
df.pivot(index="treatment", columns="gender", values="response")
# Out:
# gender      F   M
# treatment
# A          10  45
# B           5   9

# %%
df1 = df.set_index(["treatment", "gender"])
df1
# Out:
#                   age  response
# treatment gender
# A         F        15        10
#           M         4        45
# B         F        72         5
#           M        65         9

# %%
df1.unstack(level=0)
# Out:
#           age     response
# treatment   A   B        A  B
# gender
# F          15  72       10  5
# M           4  65       45  9

# %%
df1.unstack(level=1)
# Out:
#           age     response
# gender      F   M        F   M
# treatment
# A          15   4       10  45
# B          72  65        5   9

# %%
df2 = df1.swaplevel(0,1)
df2
# Out:
#                   age  response
# gender treatment
# F      A           15        10
# M      A            4        45
# F      B           72         5
# M      B           65         9

# %%
df
# Out:
#    age gender  response treatment
# 0   15      F        10         A
# 1    4      M        45         A
# 2   72      F         5         B
# 3   65      M         9         B

# %%
pd.melt(df, id_vars="treatment", value_vars=["age", "response"])
# Out:
#   treatment  variable  value
# 0         A       age     15
# 1         A       age      4
# 2         B       age     72
# 3         B       age     65
# 4         A  response     10
# 5         A  response     45
# 6         B  response      5
# 7         B  response      9

# %%
df
# Out:
#    age gender  response treatment
# 0   15      F        10         A
# 1    4      M        45         A
# 2   72      F         5         B
# 3   65      M         9         B

# %%
df.groupby("treatment").max()
# Out:
#            age gender  response
# treatment
# A           15      M        45
# B           72      M         9

# %%
df.groupby("treatment").mean()
# Out:
#             age  response
# treatment
# A           9.5      27.5
# B          68.5       7.0

# %%
df.groupby("treatment").age.max()
# Out:
# treatment
# A    45
# B     9
# Name: response, dtype: int64

# %%
df.groupby("treatment")[["age", "response"]].min()
# Out:
#            age  response
# treatment
# A            4        10
# B           65         5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
# age          4 non-null int64
# gender       4 non-null object
# response     4 non-null int64
# treatment    4 non-null object
# dtypes: int64(2), object(2)
# memory usage: 208.0+ bytes

# %% [markdown]
# as you can see gender is object
# However if we use groupby, we can convert it categorical data.
# Because categorical data uses less memory, speed up operations like groupby
#
# ```
# df["gender"] = df["gender"].astype("category")
# df["treatment"] = df["treatment"].astype("category")
# df.info()
# ```

# %%
df["gender"] = df["gender"].astype("category")
df["treatment"] = df["treatment"].astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
# age          4 non-null int64
# gender       4 non-null category
# response     4 non-null int64
# treatment    4 non-null category
# dtypes: category(2), int64(2)
# memory usage: 344.0 bytes
